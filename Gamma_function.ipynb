# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatemekm98/Image-Proccessing/blob/main/Gamma_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2,matplotlib
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Load the image
img = cv2.imread('/content/star.jpg')

# Set the gamma value
gamma = 1.8

# Create a lookup table
lookup_table = np.zeros((256, 1), dtype='uint8')

for i in range(256):
    lookup_table[i][0] = 255 * pow(float(i) / 255, 1.0 / gamma)

# Apply gamma correction using the lookup table
img_corrected = cv2.LUT(img, lookup_table)

# Display the original and corrected images
plt.imshow(img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img_corrected)

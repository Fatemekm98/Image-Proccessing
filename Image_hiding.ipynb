# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatemekm98/Image-Proccessing/blob/main/Image_hiding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2,matplotlib
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Load the cover image and the secret image
cover_img = cv2.imread('/content/me.jpg', 0 )
secret_img = cv2.imread('/content/sign blue.jpg', 0 )

# %%
secret_img.shape
# Out:
# (1280, 1172)

# %%
cover_img.shape
# Out:
# (1864, 1866)

# %%
ret, binary_secret_img1 = cv2.threshold(secret_img, 100, 255, cv2.THRESH_BINARY)

# %%
binary_secret_img1.shape
# Out:
# (1280, 1172)

# %%
secret_img1= cv2.resize(binary_secret_img1, (1864, 1866))

# Resize the secret image to match the size of the cover image
secret_img = cv2.resize(secret_img, (cover_img.shape[1], cover_img.shape[1]))

# Loop over each pixel in the cover image
for i in range(cover_img.shape[0]):
    for j in range(cover_img.shape[1]):
        # Get the binary representation of the secret image pixel value
        binary_value = format(secret_img[i, j], '08b')
        binary_pixel = format(cover_img[i, j], '08b')
        new_binary_pixel = binary_pixel[:-1]
        cover_img[i, j] = int(new_binary_pixel, 2)

# Save the stego image
cv2_imshow(cover_img)
#cv2.imwrite(cover_img[i, j])
# Out:
# <PIL.Image.Image image mode=L size=1866x1864 at 0x7F5C3F692820>
